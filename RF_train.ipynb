# %%
import kagglehub
import numpy as np
import pandas as pd
import os
import time
import multiprocessing as mp
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,f1_score,recall_score,roc_auc_score
from itertools import product

# %%
# Descargar el conjunto de datos completo
# Esto devolverá la ruta del directorio local donde se ha descargado el conjunto de datos.
dataset_root_path = kagglehub.dataset_download(
    "meowmeowmeowmeowmeow/gtsrb-german-traffic-sign"
)

# Listar todos los archivos y directorios dentro de la carpeta descargada para asegurar que estén completos
print("\nArchivos y directorios en el conjunto de datos:")
for root, dirs, files in os.walk(dataset_root_path):
    # Imprimir directorios
    for name in dirs:
        print(os.path.join(root, name) + '/')
    # Imprimir archivos
    for name in files:
        print(os.path.join(root, name))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00021_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00040_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00009_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00023_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00033_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00048_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00039_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00037_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00047_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00045_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00020_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00001_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00013_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00044_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00004_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00032_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00017_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00014_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00010_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00034_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00019_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00031_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00024_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00003_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00028_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00029_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00000_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00030_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00012_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00005_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00002_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00018_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00038_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00041_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00036_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00035_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00026_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00016_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00008_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00043_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00025_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00011_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00007_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00022_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00042_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00015_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00006_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00046_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/9/00009_00027_00003.png
# ...
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00029.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00012.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00013.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00018.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00019.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00005.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00020.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00017.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00007.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00023.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00006.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00028.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00000.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00004.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00021.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00006_00003.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00016.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00015.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00025.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00009.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00002.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00014.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00004_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00005_00024.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00026.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00001_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00008_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00010.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00001.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00027.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00000_00008.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00002_00022.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00003_00011.png
# /kaggle/input/gtsrb-german-traffic-sign/train/24/00024_00007_00000.png

# %%
#Listamos los directorios que se descargaron
#print(os.listdir('/kaggle/input/gtsrb-german-traffic-sign/'))

# %% [markdown]
# #Reducción de datos
# Vamos a reducir el dataset original de a 5k imagenes

# %%
import pandas as pd

train_csv = os.path.join(dataset_root_path, "Train.csv")

df = pd.read_csv(train_csv)

print(df.head())
print(df.shape)
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path
# 0  Train/20/00020_00000_00000.png
# 1  Train/20/00020_00000_00001.png
# 2  Train/20/00020_00000_00002.png
# 3  Train/20/00020_00000_00003.png
# 4  Train/20/00020_00000_00004.png
# (39209, 8)

# %% [markdown]
# Pasaremos (por ahora) de 39k imagenes a 5k

# %%
df_muestra = df.sample(n=30000, random_state=42)

print(df_muestra.shape)
# Out:
# (30000, 8)

# %% [markdown]
# #Preprocesamiento

# %%
from PIL import Image

X = []
y = []

#iteramos sobre el df para cargar, redimensionar y coleccionar las imagenes y etiquetas
for index, row in df_muestra.iterrows():
    # construimos la ruta completa hacia las imagenes
    image_path = os.path.join(dataset_root_path, row['Path'])

    try:
        #cargar la imagen
        img = Image.open(image_path)
        img = img.resize((96, 96)) #primero fue de 32px-> 64px, ->96px
        #Convertimos la imagen a un arreglo para integrarla a X
        X.append(np.array(img))
        #Integramos ClassId a y
        y.append(row['ClassId'])
    except Exception as e:
        print(f"Error procesando {image_path}: {e}")

# Convertir las listas a arreglos
X = np.array(X)
y = np.array(y)

print(f"Dimensiones de imagenes procesadas (X): {X.shape}")
print(f"Dimensiones de etiquetas (y): {y.shape}")
# Out:
# Dimensiones de imagenes procesadas (X): (30000, 96, 96, 3)
# Dimensiones de etiquetas (y): (30000,)

# %%
import cv2
#aplicaremos filtro gaussiano a cada imagen en X. Inicialmente se aplicó (5,5) pero no dio buenos resultados, reducimos a (3,3)
#El valor 0 indica que la desviación estándar en las direcciones X e Y se calcula a partir del tamaño del kernel
X_smoothed = np.array([cv2.GaussianBlur(img, (3, 3), 0) for img in X])

print(f"dimensiones de imagenes suavizadas(X_smoothed): {X_smoothed.shape}")
# Out:
# dimensiones de imagenes suavizadas(X_smoothed): (30000, 96, 96, 3)

# %% [markdown]
# ### SIFT
#
# Es más comun realizar sift sobre grises perp considerando que el color es importante para este conjunto ya que colores como amarillo, rojos y blancos son de importancia visual va a dejar esta configuracion. Inicialmente sí se hizo sobre grises pero no dio buenos resultados

# %%
import cv2

#inicializar sift
sift = cv2.SIFT_create()

all_descriptors = []

for i, img_gray in enumerate(X_smoothed):
    # Detectar keypoints y descriptores
    keypoints, descriptors = sift.detectAndCompute(img_gray, None)

    if descriptors is not None:
        all_descriptors.append(descriptors)

# Concatenar todos los descriptores en un único array NumPy
# Este array se utilizará para entrenar el vocabulario BOVW

if all_descriptors:
    all_descriptors_np = np.vstack(all_descriptors)
    print(f"Total SIFT descriptores extraídos: {all_descriptors_np.shape}")
else:
    all_descriptors_np = np.array([])
    print("No se extrayeron descriptores SIFT.")
# Out:
# Total SIFT descriptores extraídos: (943903, 128)

# %% [markdown]
# ### Creación de vocabulario de bolsa de palabras visuales (BoVW)
# Ahora, crearemos un vocabulario visual agrupando los descriptores SIFT mediante K-Means

# %%
from sklearn.cluster import MiniBatchKMeans

#definimos el numero de palabras visuales (clusters)
k = 2000

if all_descriptors_np.shape[0] > 0:
   # Usamos MiniBatchKMeans para mayor eficiencia con grandes conjuntos de datos
   # Es una alternativa más rápida a KMeans
    kmeans = MiniBatchKMeans(n_clusters=k, random_state=42, n_init='auto', verbose=False)
    kmeans.fit(all_descriptors_np)
    visual_vocabulary = kmeans.cluster_centers_
    print(f"Dimensiones del vocabulario visual: {visual_vocabulary.shape}")
else:
    print("No se pudo crear vocabulario,sin descriptores.")
    visual_vocabulary = None
# Out:
# Dimensiones del vocabulario visual: (2000, 128)

# %% [markdown]
# Pruebas con 5k imagenes
# * 1ro: Dimensiones del vocabulario visual: (100,128)
# * 2do: Dimensiones del vocabulario visual: (500, 128)
# * 3ro: Dimensiones del vocabulario visual: (1000, 128)
#
# pruebas con 8k imagenes
# * Dimensiones del vocabulario visual: (1000, 128)

# %% [markdown]
# ### Generación de vectores de características BoVW
# Tras crear el vocabulario, representaremos cada imagen como un histograma de estas palabras visuales. Este histograma cuenta cuántas veces aparece cada palabra visual en una imagen.

# %%
if visual_vocabulary is not None:
    # Inicializar BOWImgDescriptorExtractor
    # Utiliza el detector SIFT y el vocabulario KMeans para generar histogramas
    bow_extractor = cv2.BOWImgDescriptorExtractor(sift, cv2.BFMatcher(cv2.NORM_L2))
    bow_extractor.setVocabulary(visual_vocabulary)

    # Generar vectores de características BoVW para cada imagen
    bovw_features = []
    for img_gray in X_smoothed:
        keypoints = sift.detect(img_gray, None)
        # Calcula el histograma BoVW para la imagen
        if keypoints:
            features = bow_extractor.compute(img_gray, keypoints)
            if features is not None:
                bovw_features.append(features.flatten())
            else:
                # Si el cálculo devuelve None, agregue un vector cero
                bovw_features.append(np.zeros(k))
        else:
            #Si no se detectan puntos clave, agregue un vector cero.
            bovw_features.append(np.zeros(k))

    bovw_features_np = np.array(bovw_features)
    print(f"Características BoVW generadas con dimension: {bovw_features_np.shape}")
else:
    bovw_features_np = None
    print("No se pueden generar las características de BoVW, falta el vocabulario.")
# Out:
# Características BoVW generadas con dimension: (30000, 2000)

# %% [markdown]
# Pruebas con 5k imagenes
# 1. Características BoVW generadas con dimension: (5000, 100)
# 2. Características BoVW generadas con dimension: (5000, 500)
# 3. Características BoVW generadas con dimension: (5000, 1000)
#
# Pruebas con 8k imagenes
# 1. Características BoVW generadas con dimension: (8000, 1000)

# %% [markdown]
# ### Análisis de Componentes Principales (PCA)
# Finalmente, aplicaremos PCA para reducir la dimensionalidad de los vectores de características BoVW, lo que puede ayudar a mejorar el rendimiento del modelo y reducir el tiempo de cálculo, especialmente si el espacio de características es muy grande

# %%
from sklearn.decomposition import PCA

if bovw_features_np is not None and bovw_features_np.shape[0] > 0:
  # Inicializar el PCA, conservando el 95% de la varianza
  # También se puede especificar un número fijo de componentes, por ejemplo, n_components=50
    pca = PCA(n_components=500, random_state=42)

    #Adaptar PCA a las características de BoVW y transformarlas
    bovw_features_pca = pca.fit_transform(bovw_features_np)

    print(f"características BoVW después de PCA: {bovw_features_pca.shape}")
    print(f"número de componentes seleccionados por PCA: {pca.n_components_}")
else:
    bovw_features_pca = None
    print("No se pudo aplicar PCA. Sin características BoVW .")
# Out:
# características BoVW después de PCA: (30000, 500)
# número de componentes seleccionados por PCA: 500

# %% [markdown]
# Pruebas con 5k imagenes
# 1. características BoVW después de PCA: (5000, 76)
# número de componentes seleccionados por PCA: 76
#
# 2. características BoVW después de PCA: (5000, 325)
# número de componentes seleccionados por PCA: 325
#
# 3. características BoVW después de PCA: (5000, 579)
# número de componentes seleccionados por PCA: 579
#
# Pruebas con 8k imagenes
# 1. características BoVW después de PCA: (8000, 620)
# número de componentes seleccionados por PCA: 620

# %% [markdown]
# # RF

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(bovw_features_pca, y, test_size=0.2, random_state=42)

# Paralelo Random Forest
def rb_train(data):
    X_sub, y_sub = data
    model = RandomForestClassifier(
        n_estimators=100,
        random_state=42
    )
    model.fit(X_sub, y_sub)
    return model

tiempos_rf = []
accura_rf = []

# Número de procesos
NUM_PROCESOS_MAX = 7

for i in range(2, NUM_PROCESOS_MAX + 1):
    # dividir dataset para el número actual de procesadores 'i'
    indices = np.array_split(np.arange(len(X_train)), i)
    data_splits = [(X_train[idx], y_train[idx]) for idx in indices]

    start_par_rf = time.time()

    with mp.Pool(processes=i) as pool:
        rf_models = pool.map(rb_train, data_splits)

    t_par_rf = time.time() - start_par_rf

    # usar el primer modelo para evaluar
    pred_par_rf = rf_models[0].predict(X_test)
    acc_par_rf = accuracy_score(y_test, pred_par_rf)

    print(f"Procesadores: {i}")
    print(f"Tiempo paralelo RF: {t_par_rf:.2f} segundos")
    print(f"Accuracy RF (usando un modelo): {acc_par_rf:.4f}")
    print("\n")

    tiempos_rf.append(t_par_rf)
    accura_rf.append(acc_par_rf)

print("Tiempos de ejecución paralela (RF):")
print(tiempos_rf)
print("Accuracys paralelas (RF):")
print(accura_rf)
# Out:
# Procesadores: 2
# Tiempo paralelo RF: 30.80 segundos
# Accuracy RF (usando un modelo): 0.6790
#
#
# Procesadores: 3
# Tiempo paralelo RF: 19.33 segundos
# Accuracy RF (usando un modelo): 0.6657
#
#
# Procesadores: 4
# Tiempo paralelo RF: 13.59 segundos
# Accuracy RF (usando un modelo): 0.6420
#
#
# Procesadores: 5
# Tiempo paralelo RF: 11.12 segundos
# Accuracy RF (usando un modelo): 0.6355
#
#
# Procesadores: 6
# Tiempo paralelo RF: 9.18 segundos
# Accuracy RF (usando un modelo): 0.6230
#
#
# Procesadores: 7
# Tiempo paralelo RF: 7.64 segundos
# Accuracy RF (usando un modelo): 0.6125
#
#
# Tiempos de ejecución paralela (RF):
# [30.796499013900757, 19.333328247070312, 13.593487024307251, 11.124950885772705, 9.177236795425415, 7.643477201461792]
# Accuracys paralelas (RF):
# [0.679, 0.6656666666666666, 0.642, 0.6355, 0.623, 0.6125]
